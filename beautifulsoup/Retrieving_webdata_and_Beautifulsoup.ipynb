# %% [markdown]
# # Using Beautifulsoup to read the html pages

# %%
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl
from IPython import display

# %%
# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input('Enter - ')
html = urllib.request.urlopen(url, context=ctx).read()
soup = BeautifulSoup(html, 'html.parser')

# Retrieve all of the anchor tags
tags = soup('a')

for tag in tags:
    print(tag.get('href' , None))
# Out:
# Enter - https://en.wikipedia.org/wiki/HMS_Beagle
# None
# #mw-head
# #searchInput
# /wiki/List_of_ships_named_HMS_Beagle
# /wiki/File:PSM_V57_D097_Hms_beagle_in_the_straits_of_magellan.png
# /wiki/Straits_of_Magellan
# /wiki/Monte_Sarmiento
# /wiki/Robert_Taylor_Pritchett
# /wiki/The_Voyage_of_the_Beagle
# /wiki/Cherokee-class_brig-sloop
# /wiki/Brig-sloop
# /wiki/Builder%27s_Old_Measurement
# #cite_note-FOOTNOTEFitzRoy1839[httpdarwin-onlineorgukcontentframesetviewtypetextitemIDF102pageseq40_17–18]-1
# /wiki/Brig
# /wiki/Barque
# /wiki/Cherokee-class_brig-sloop
# /wiki/Sloop-of-war#Rigging
# /wiki/Royal_Navy
# /wiki/Pound_sterling
# /wiki/Ship_naming_and_launching
# /wiki/Woolwich_Dockyard
# /wiki/River_Thames
# /wiki/George_IV_of_the_United_Kingdom
# /wiki/London_Bridge
# /wiki/Man-of-war
# #cite_note-FOOTNOTETaylor200822–24,_36-2
# #cite_note-FOOTNOTEStokes1846[httpsarchiveorgdetailsdiscoveriesinaus00stokpage3_3]-3
# /wiki/Reserve_Fleet_(United_Kingdom)
# /wiki/Barque
# ...

# %% [markdown]
# # Unicode characters and strings

# %%
display.Image("/Users/vinod/Desktop/Programming/python_webdata/beautifulsoup/UTF-8.png")

# %%
display.Image("/Users/vinod/Desktop/Programming/python_webdata/beautifulsoup/Unicode_and_UTD-8.png")

# %% [markdown]
# # Retrieving Web Pages

# %%
display.Image("/Users/vinod/Desktop/Programming/python_webdata/beautifulsoup/Urllib.png")

# %%
display.Image("/Users/vinod/Desktop/Programming/python_webdata/beautifulsoup/Url#2.png")

# %% [markdown]
# # Parsing Web Pages

# %%
display.Image("/Users/vinod/Desktop/Programming/python_webdata/beautifulsoup/web_scraping.png")

# %%
display.Image("/Users/vinod/Desktop/Programming/python_webdata/beautifulsoup/web_scraping_1.png")
